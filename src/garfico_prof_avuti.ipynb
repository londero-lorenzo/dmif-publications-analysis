# %%
from pyvis.network import Network
import networkx as nx
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

# %%
with open("./data/prof_avuti.txt", "r", encoding="utf-8") as f:
    professori_avuti = [riga.strip() for riga in f]

def normalize_prof(name):
    cognome, nome = [x.strip() for x in name.split(',')]
    return f"{cognome} {nome}"

professori_avuti = set(normalize_prof(n) for n in professori_avuti)
professori_avuti = list(professori_avuti)
professori_avuti.sort()
print(professori_avuti)
# Out:
# ['Bozzo Enrico', 'Brajnik Giorgio', 'Buttussi Fabio', 'Chittaro Luca', 'Coppola Paolo', 'Della Mea Vincenzo', 'Della Monica Dario', 'D’Agostino Giovanna', 'Fontana Federico', 'Formisano Andrea', 'Geatti Luca', 'Liessi Davide', 'Maddalena Eddy', 'Mameli Valentina', 'Miculan Marino', 'Mirolo Claudio', 'Mizzaro Stefano', 'Montanari Angelo', 'Piazza Carla', 'Puppis Gabriele', 'Riccio Vincenzo', 'Ritacco Ettore', 'Scagnetto Ivan', 'Serra Giuseppe', 'Vidoni Paolo']
