# %%
from pyvis.network import Network
import networkx as nx
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

# %% [markdown]
# <h1>Converti file csv in pickle</h1>

# %% [markdown]
# <h2>Lista di professori del dipartimento di informatica</h2>

# %%
with open("C:/Users/giova/Documents/Universita/Anno3/SocialComputing/Laboratorio/Progetto/data/professori_dipartimento_inf.txt", "r", encoding="utf-8") as f:
    professori_informatica = [riga.strip() for riga in f]

def normalize_prof(name):
    cognome, nome = [x.strip() for x in name.split(',')]
    return f"{cognome} {nome}"

professori_informatica = set(normalize_prof(n) for n in professori_informatica)
professori_informatica = list(professori_informatica)
professori_informatica.sort()
print(professori_informatica)
# Out:
# ['Bellettini Giovanni', 'Bozzo Enrico', 'Brajnik Giorgio', 'Burigat Stefano', 'Buttussi Fabio', 'Chittaro Luca', 'Cimatti Alessandro', 'Comini Marco', 'Coppola Paolo', 'Dattolo Antonina', 'Della Mea Vincenzo', 'Della Monica Dario', 'Di Gianantonio Pietro', 'Dimonte Vincenzo', 'Dovier Agostino', 'Drioli Carlo', 'D’Agostino Giovanna', 'Fogolari Federico', 'Fontana Federico', 'Formisano Andrea', 'Fortuna Sara', 'Franceschet Massimo', 'Fusiello Andrea', 'Geatti Luca', 'Lancia Giuseppe', 'Lenisa Marina', 'Liessi Davide', 'Maddalena Eddy', 'Mameli Valentina', 'Micheloni Christian', 'Miculan Marino', 'Mirolo Claudio', 'Mizzaro Stefano', 'Montanari Angelo', 'Omero Paolo', 'Pace Luigi', 'Piazza Carla', 'Policriti Alberto', 'Puppis Gabriele', 'Riccio Vincenzo', 'Ritacco Ettore', 'Roitero Kevin', 'Romani Giulio', 'Scagnetto Ivan', 'Serra Giuseppe', 'Vermiglio Rossana', 'Vidoni Paolo']

# %% [markdown]
# <h2>DataFrame sugli articoli di Informatica</h2>

# %%
df_informatica = pd.read_csv('C:/Users/giova/Documents/Universita/Anno3/SocialComputing/Laboratorio/Progetto/data/informatica.csv')

df_informatica.head()
# Out:
#                                              Authors  \
# 0                              Mari, M.; Snidaro, L.
# 1                              Mari, M.; Snidaro, L.
# 2  Ceschia, S.; Di Gaspero, L.; Rosati, R.M.; Sch...
# 3                                     Pagliarini, R.
# 4  Madni, H.A.; Shujat, H.; de Nardin, A.; Zottin...
#
#                                    Author full names  \
# 0  Mari, Marco (59388337700); Snidaro, Lauro (650...
# 1  Mari, Marco (59388337700); Snidaro, Lauro (650...
# 2  Ceschia, Sara (35193496000); Di Gaspero, Luca ...
# 3                  Pagliarini, Roberto (25229039800)
# 4  Madni, Hussain Ahmad (57195220347); Shujat, Ha...
#
#                                         Author(s) ID  \
# 0                            59388337700; 6507499895
# 1                            59388337700; 6507499895
# 2   35193496000; 6505944235; 57406536600; 6701629145
# 3                                        25229039800
# 4  57195220347; 59705771800; 57259162600; 5795942...
#
#                                                Title  Year  \
# 0  Survey of Neural Network Approaches to Target ...  2026
# 1  Ensemble of KalmanNets with innovation-based a...  2026
# 2  Multi-neighborhood simulated annealing for the...  2026
# 3  Differential Flux-Balance Analysis Infers Meta...  2026
# 4  FsBAD: Data-efficient feature reconstruction f...  2026
#
#                                         Source title      Volume Issue  \
# 0                                 Information Fusion         127   NaN
# 1                                 Information Fusion         127   NaN
# 2  International Transactions in Operational Rese...          33     1
# 3                  Lecture Notes in Computer Science  16051 LNCS   NaN
# 4                        Pattern Recognition Letters         199   NaN
#
#   Art. No. Page start  ...                                               ISBN  \
# 0   103789        NaN  ...                                                NaN
# 1   103777        NaN  ...                                                NaN
# 2      NaN         38  ...                                                NaN
# 3      NaN        155  ...  9789819698936; 9789819698042; 9789819698110; 9...
# 4      NaN        113  ...                                                NaN
#
#    CODEN  PubMed ID Language of Original Document  Abbreviated Source Title  \
# 0    NaN        NaN                       English               Inf. Fusion
# 1    NaN        NaN                       English               Inf. Fusion
# 2    NaN        NaN                       English    Int. Trans. Oper. Res.
# 3    NaN        NaN                       English  Lect. Notes Comput. Sci.
# 4    NaN        NaN                       English     Pattern Recogn. Lett.
#
#       Document Type Publication Stage  \
# 0           Article             Final
# 1           Article             Final
# 2           Article             Final
# 3  Conference paper             Final
# 4           Article             Final
#
#                                 Open Access  Source                  EID
# 0  All Open Access; Hybrid Gold Open Access  Scopus  2-s2.0-105017548985
# 1                                       NaN  Scopus  2-s2.0-105017546340
# 2  All Open Access; Hybrid Gold Open Access  Scopus   2-s2.0-85211480324
# 3                                       NaN  Scopus  2-s2.0-105022894987
# 4  All Open Access; Hybrid Gold Open Access  Scopus  2-s2.0-105021263351
#
# [5 rows x 34 columns]

# %%
df_informatica.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Affiliations',
#        'Authors with affiliations', 'Abstract', 'Author Keywords',
#        'Index Keywords', 'Correspondence Address', 'Editors', 'Publisher',
#        'ISSN', 'ISBN', 'CODEN', 'PubMed ID', 'Language of Original Document',
#        'Abbreviated Source Title', 'Document Type', 'Publication Stage',
#        'Open Access', 'Source', 'EID'],
#       dtype='object')

# %% [markdown]
# <h2>DataFrame sugli articoli di matematica</h2>

# %%
df_matematica = pd.read_csv('C:/Users/giova/Documents/Universita/Anno3/SocialComputing/Laboratorio/Progetto/data/matematica.csv')

# %% [markdown]
# <h2>Funzione per estrarre gli autori dal campo 'Author full names'</h2>

# %%
import re

def extract_authors(author_string):
    chunks = [x.strip() for x in author_string.split(';')]
    authors = []
    for c in chunks:
        match = re.match(r"([^,]+),\s*([^(]+)", c)
        if match:
            cognome = match.group(1).strip()
            nome = match.group(2).strip()
            authors.append(f"{cognome} {nome}")
    return authors

# %%
import itertools

autori_informatica = set(
    itertools.chain.from_iterable(
        df_informatica["Author full names"].apply(extract_authors)
    )
)
autori_informatica = list(autori_informatica)
autori_informatica
# Out:
# ['Ciapessoni Emanuele',
#  'Cadoli Marco',
#  'Corriveau François',
#  'Xu Hanlin',
#  'Polikarpov Alexey Ph',
#  'Schmitt N.',
#  'Geatti Paola',
#  'Dollfus Phillippe',
#  'Karas Vladimír',
#  'Fisher Wade C.',
#  'Boscolo Stefano',
#  'Viel Michele',
#  'Hays Jonathan M.',
#  'Rachevski Alexandre',
#  'Loffredo Salvatore',
#  'Oppen H.',
#  'Sultansoy S.',
#  'Zhang Chunhu',
#  'Cella Giancarlo C.',
#  'Haug Sigve',
#  'Hanke M. M.',
#  'Van Thourhout Dries Vam',
#  'Kreczko Lukasz',
#  'Mohamed A. Tarek Abouelfadl',
#  'Yang Biao',
#  'Ferri Cesar',
#  'Girotto Mauro',
#  'Gayathri V.',
#  'Muleri Fabio',
#  'Yang Jiawei',
#  'Rizvi E.',
#  'Cannistraci Irene',
#  'Marcoccia L.',
#  'Moussaouy A. El',
#  'Kingston M. K.',
#  'Babal D.',
#  'Fröhling Leon',
#  'Augenstein Isabelle',
#  'Garcez Artur D’Avila',
#  'Ayling Sarah C.',
#  'Yang Chun',
#  'Nibigira Emery',
#  'del Pioluogo Nicola',
#  'Luiten Jonathon',
#  'Dingfelder Jochen Christian',
#  'Apicella Andrea',
#  'Rowlinson Samuel J.',
#  'Ivanov Alexander A.',
#  'Zhang Lichao',
#  'Graur I. A.',
#  'Solans Sanchez Carlos A.',
#  'Paulo Octávio Salgueiro',
#  'Sarker Anindita',
#  'Padkan Nazanin',
#  'Mastrandrea Paolo',
#  'Coelho Barrue R. F.',
#  'Lu M.',
#  'Lindon Joseph H.',
#  'Anderson A. C.',
#  'Gustavino G.',
#  'Passantino Alessandro',
#  'Magaña-Sandoval Fabian',
#  'Niederl Josef',
#  'Song Jiangbo',
#  'Zarrella Angelo',
#  'Floridi Alessandro G.',
#  'Alati Caterina',
#  'Montemanni Roberto',
#  'Prast Julie',
#  'Zorbas T. G.',
#  'de Martino Francesco Marco',
#  'Walker S. D.',
#  'Pastor O. Estrada',
#  'Liu M. Y.',
#  'Torelli Lucio',
#  'Petousis Vlasios',
#  'Tanskanen Jaakko A.',
#  'Elmasri Ramez A.',
#  'He Xiangyu',
#  'Urbán Jozef',
#  'Marini Marco Raoul',
#  'Ballabene E.',
#  'Barkeloo Jason T.',
#  'Fedukov R. A.',
#  'Mindur B.',
#  'Connell Simon H.',
#  'Qualizza Andrea',
#  'Vigani Luigi',
#  'Bruni Roberto',
#  'Potti H.',
#  'Sanfilippo L.',
#  'Dobre Monica',
#  'Delgado J.',
#  'Zhao Qing',
#  'Yeşilada Yeliz',
#  'Zaitsev Alexander M.',
#  'Conti Giamaica',
#  'Will Sebastian',
#  'Wang Liang',
#  'Cortiula Francesco',
#  'Camponogara Eduardo',
#  'Trail E. A.',
#  'Bank Balázs',
#  'Groth Marco',
#  'Falda Ulhoa Coelho L. F.',
#  'Li Huaishen',
#  'Stefanini Marco',
#  'Ferrari Carlo',
#  'Levêque Jessica',
#  'Usman Samantha A.',
#  'Bate R.',
#  'Scarfó Giuseppe',
#  'Hayes Fergus J.',
#  'Basilicata Manuela Giovanna',
#  'Asinari Pietro',
#  'Pesarin Anna',
#  'Schwemling Ph',
#  'Sullivan M. J.',
#  'Camp Jordan B.',
#  'Karkout Osama',
#  'Abramo E.',
#  'Ballestra Alberto',
#  'Tornelli Carlo',
#  'Marchese Luigi',
#  'Leney Katharine J.C.',
#  'Paderno Diego',
#  'Ceterchi Rodica',
#  'Libralato Michele',
#  'Aprile Giuseppe',
#  'Molinari Alberto',
#  'Pisch Alexander',
#  'Pizzato Mattia',
#  'Hanks Jonathan Ali',
#  'Tosciri Cecilia',
#  'Costanzo Davide',
#  'Fanti Marcello',
#  'Garelli Nicoletta',
#  'Bayley Joseph C.',
#  'Hauptmann Alexander Georg',
#  'Griess Verena C.',
#  'Gagno Sara',
#  'Amoroso Simone',
#  'Nakashidze Irina I.',
#  'Azzollini Daniela',
#  'Wu Chao',
#  'Di Luca Massimiliano',
#  'Spanó F.',
#  'Petersen Andrew K.',
#  'De Sabbata Stef',
#  'Noori Moslem',
#  'Becherer F.',
#  'Kirby Michael H.',
#  'Alessandro Rizzi',
#  'Montangero Carlo',
#  'Diaz Capriles F. G.',
#  'Diehl Roland D.',
#  'Menna Fabio',
#  'Guerrieri Antonio',
#  'Huang Qiushi',
#  'Cucchiaro Sara',
#  'Tasson Jay D.',
#  'Hod Noam Tal',
#  'Cordero Francesca',
#  'Zweig Katharina A.',
#  'Colombo Roberto',
#  'Priori Roberta',
#  'Castiglioni Valentina',
#  'Daw Edward J.',
#  'Albarelli Andrea',
#  'Dziurda Agnieszka',
#  'Kemkes Philipp',
#  'Zeng Hao',
#  'Galazzi Alessandro',
#  'Campanella Sara',
#  'Campiglia Pietro',
#  'Bansal Sunil',
#  'van Bulck David',
#  'Cristinziani M.',
#  'Lee Chienhsiu Hsiu',
#  'Mhaske Ashish A.',
#  'Engels A. Arbet',
#  'Palestra P.',
#  'Sentance Sue',
#  'Micheletti Diego',
#  'Albrecht Johannes',
#  'Masu Raul',
#  'Ren Haoyu',
#  'Biswas Diptaparna',
#  'Tokushuku Katsuo',
#  'Semple Charles',
#  'Bianco Gianluca',
#  'Guardia A. Berrocal',
#  'Zavagno Daniele',
#  'Hanabata Yoshitaka',
#  'Adam Lennart',
#  'Luci Claudio',
#  'Caiti A.',
#  'Stonjek Stefan',
#  'Gargiulo S.',
#  'Chen Yanjie',
#  'Sarti Luigi',
#  'Rosa Giovanni La',
#  'Ambrosi Giovanni',
#  'Law Mark',
#  'Rapisarda Massimo',
#  'Dornel Erwan',
#  'Balletti Caterina',
#  'Kraus A. C.',
#  'Muscogiuri Luciana',
#  'Newhouse Robin',
#  'Brooijmans Gustaaf',
#  'Chou Yi Shiuan',
#  'Martinez-Suarez Paula',
#  'Sala Giovanni',
#  'Coppola Paolo',
#  'Beemster L. J.',
#  'Gu Yang',
#  'Burghgrave Blake',
#  'Ciancaleoni Gianluca',
#  'Feicht Jon R.',
#  'Makris Nikolaos',
#  'Huet Dominique',
#  'Hager Gustav',
#  'Asanovski Ruben',
#  'Aricò Antonino Salvatore',
#  'Matakias D.',
#  'Salibra Antonino',
#  'Pankow Christopher',
#  'Navarrete Michelini Pablo',
#  'Guigó Roderic',
#  'Gutmann Michael U.',
#  'Vu Xuan Son',
#  'Antonetti Lamorgese Passeri Cristina',
#  'Shojaei Barjuei Erfan',
#  'Lorenz Frank P.',
#  'Mühling Andreas Michael',
#  'Sandaker Heidi',
#  'Song Zhaoliang',
#  'Reich Alexander',
#  'Tokanai Fuyuki',
#  'Biasizzo Jessica',
#  'Cavallaro Andrea',
#  'Dzhafarov Damir D.',
#  'Cranshaw Jack M.',
#  'Gallas Elizabeth J.',
#  'Cacchiani Valentina',
#  'Barkett Kevin',
#  'Console Luca',
#  'Esseni David',
#  'Yang Hongtao T.',
#  'Russo Gaetano',
#  'Bilenko Igor A.',
#  'Li Jiahao',
#  'Yan S.',
#  'Maggiolo-Schettin Andrea',
#  'Davidson Drew',
#  'Guidorzi Cristiano',
#  'Takeda Yukio',
#  'Khrabrykh Zinaida V.',
#  'Maniezzo Vittorio',
#  'Gullo Giuseppe',
#  'Akiyama Daiya',
#  'Arreghini Antonio',
#  'Abdari Ali',
#  'Hrupec Dario',
#  'Hubaut Fabrice',
#  'Vitale Salvatore',
#  'Martincigh Matteo',
#  'Krawiec Halina',
#  'Khadka S.',
#  'Penzin Maksim S.',
#  'Pagan-Griso Simone',
#  'Gorini Benedetto',
#  'Hedderman Paul',
#  'Gattiglia Gabriele',
#  'Kushida Junko',
#  'Lee Steve',
#  'Hamer Matthias',
#  'Cheng Ziyi',
#  'Lyon Adam L.',
#  'Aikot Aravind',
#  'Bresolin Davide',
#  'Klein Max H.',
#  'Buanes Trygve',
#  'Røhne Ole Myren',
#  'Miyazaki Tsuyoshi',
#  'Volpe Paolo',
#  'Balek Petr',
#  'Yamatani M.',
#  'Bruers Ben',
#  'Morisbak Vanja',
#  'Mukherjee Soma',
#  'Muñiz Erik A.M.',
#  'Shahnawaz Soyfoo Muhammad',
#  'Accardo P. Agostino',
#  'Baschirotto A.',
#  'Ercolessi Furio',
#  'Denisov Sergey P.',
#  'Esposito Stefano',
#  'Hyneman R.',
#  'Volpi F.',
#  'Albicocco Pietro',
#  'Evans Matthew R.',
#  'Srivastava Varun',
#  'Grado Aniello',
#  'Michelotto Michele',
#  'Bhimji Wahid',
#  'Zheng Yaozong',
#  'Das Abir',
#  'Badami Oves',
#  'Huang S.',
#  'Huson Daniel H.',
#  'Marin Elia',
#  'Petrič Marko',
#  'Martinez Agullo P.',
#  'Fishbach Maya',
#  'Iacuzzi Silvia',
#  'Ferro Federico',
#  'Scherling Laura',
#  'Sieniawska Magdalena',
#  'Di Ruzza Benedetto',
#  'Gragnaniello Daniela',
#  'Sietis Nina',
#  'Hirose Minoru',
#  'Giordano Claudia',
#  'Yamamoto Toshiro',
#  'MacQuet Adrian',
#  'Alier Forment Marc Forment',
#  'Yuasa Hideo',
#  'Waugh Benedict M.',
#  'Pesce F.',
#  'Franco Luca',
#  'Scantamburlo Teresa',
#  'Cao Yun',
#  'Baruzzo Marco',
#  'Cristofoli Andrea',
#  'Verdeil Alexandra',
#  'van Duuren Michiel J.',
#  'Gress T.',
#  'Webb A. F.',
#  'Virgili Andrea',
#  'Orsini Fabienne',
#  'Lavrinenko Akim',
#  'Gity Farzan',
#  'Conde-González Miguel Ángel',
#  'Paglietti P.',
#  'Rissone Paolo',
#  'Allbrooke B. M.M.',
#  'Yuan Kun',
#  'Vitti Stefano',
#  'Cannizzaro Renato',
#  'Cahillane Craig',
#  'Tenaglia Giacomo',
#  'Sciarrone Giulia',
#  'Lasky Paul D.',
#  'Wong-Toi Howard',
#  'Reda Gianluigi',
#  'Mian Giovanni',
#  'Sadrozinski Hartmut F.W.',
#  'Antoniazzi Fulvio',
#  'Honseil Furio',
#  'Caviedes Betancourt L. J.',
#  'Tornambe P.',
#  'Berardi Anna C.',
#  'Karimov Artur I.',
#  'Pakarinen Jyri',
#  'Tskhadadze Edisher G.',
#  'Torrente Yvan',
#  'Gugel R.',
#  'Mucelli Raffaella Pozzi',
#  'Stefanidis Kyriakos G.',
#  'Sykora Martin',
#  'Bezshyiko Iaroslava',
#  'Grenier Isabelle A.',
#  'Koch Simon Florian',
#  'Stamenkovic Marko',
#  'Zanato Massimiliano',
#  'Martínez Mario',
#  'Principe Giacomo',
#  'Gargiulo Isacco Ciro',
#  'Ritacco Ettore',
#  'Chaibi O.',
#  'Senthilkumar V.',
#  'Takubo Yosuke',
#  'Chen Xingyu',
#  'Singh Sukhman',
#  'Gardner Robert William',
#  'De Luca Ernesto William',
#  'Sowell Eric',
#  'Guedel Manuel',
#  'Burden Annette',
#  'Gispert Maria A.',
#  'Egidi Lavinia',
#  'George Simon',
#  'Moussa Fadl',
#  'van der Schaaf Laura V.D.',
#  'Bauce Matteo',
#  'Slanina Matteo',
#  'Yorita Kohei',
#  'Zancola Andrea',
#  'Seedorf Jan',
#  'Palù Francesca',
#  'Maiboroda Vera',
#  'Marques João Lourenço',
#  'Redamalla Rekha',
#  'Zavattaro Gianluigi',
#  'Ejeh Dennis Glenn',
#  'Zong Ziyao',
#  'Karpova Z. M.',
#  'Hak Kim Byeong',
#  'Grapulin Michele',
#  'Jonker R. J.G.',
#  'Vinck Adrianus Johannes Han',
#  'Černčič Eva',
#  'McNamara Peter Charles',
#  'Gellrich Andreas',
#  'Ricci Giuseppe',
#  'Brooks E. M.',
#  'la Rocca Gevisa',
#  'Farinelli Luca',
#  'Silva Ferreira I.',
#  'Silvello Gianmaria',
#  'Gouighri M.',
#  'Rompotis Nikolaos',
#  'Corpe Louie Dartmoor',
#  'Chelkov Georgy A.',
#  'Lavery Paul S.',
#  'da Costa João Barreiro Guimarães',
#  'Navarro Silvia Adriana',
#  'Schade Robert',
#  'Drago Marco',
#  'Hance Mike',
#  'Paluru Naveen',
#  'Choo Jiyeon',
#  'Huang X.',
#  'Prinetto Paolo',
#  'Langrekken O. K.B.',
#  'Santini Carolina',
#  'Celebi Emre',
#  'Chiţan Adrian',
#  'Kortsarz Guy',
#  'Jarvis Erich D.',
#  'Rodà Antonio',
#  'Giusti Christian',
#  'Heitmann Henrich',
#  'Falcone Alberto',
#  'Angelova S. V.',
#  'García-Rojo Marcial',
#  'Cerdá-Durán Pablo',
#  'Mondal Spandan',
#  'Montella Alessandro',
#  'Muse J. M.',
#  'Menegon Davide',
#  'Thielmann O.',
#  'Jiang Yi',
#  'Benini Luca',
#  'Conti Antonello',
#  'Protopopescu Serban D.',
#  'Käpylä Jani',
#  'Naquin Delphine',
#  'Dozzi Manuele',
#  'Sillani Sandro',
#  'D’Accolti Maria',
#  'Omero Paolo',
#  'Maiuolo Jessica',
#  'Caffaro A. G.Garcia',
#  "O'Shaughnessy Richard",
#  'Basso Massimiliano',
#  'Scheffler Matthias',
#  'Li Yingping',
#  'McPherson Robert A.',
#  'Kourou Konstantina D.',
#  'Neilson Joshua',
#  'Corbeil Jacques',
#  'Carter T. M.',
#  'Gkountoumis Panagiotis',
#  'Byström Katriina',
#  'Oreglia M. J.',
#  'Hallewell Gregory D.',
#  'Weber Michele S.',
#  'Adachi Tetsuya',
#  'Geng C.',
#  'Gagnon Louis Guillaume',
#  'Scapin Emanuele',
#  'Cornaro Cristina',
#  'Jakobs Karl',
#  'Viceré Andrea',
#  'Wa̧s Michał',
#  'Thornberry R. E.',
#  'Marsh Ben',
#  'Navarro Laura Barranco',
#  'Peng Jinjia',
#  'Maguire Helen',
#  'Westby Per H.',
#  'Dumancic Mirta',
#  'Fan Cunwei',
#  'Moretti Elisa',
#  'Modha Sandip',
#  'Brambillaschi Giuseppe',
#  'Abbott Thomas D.',
#  'Tian Y.',
#  'de Stefani Marco Alvise',
#  'Hong Tae-min',
#  'Burton Charles D.',
#  'Zanuttigh Pietro',
#  'Zhang Xinfeng',
#  'Orellana G. E.',
#  'Istrail Sorin C.',
#  'Sala Alessandro',
#  'Shao Pengcheng',
#  'Easter Paul J.',
#  'Vidiri Annalisa',
#  'Heng Ik Siong',
#  'Standke Mark',
#  'Soffer Abner',
#  'Pang Hao',
#  'Frappa Giada',
#  'Kim D. W.',
#  'Tavecchio Fabrizio',
#  'Lu Wei',
#  'Morinaga Masahiro',
#  'Hangal Dhanush Anil',
#  'Iori M.',
#  'Pirani Alessandro',
#  'Wilson Scott',
#  'Nakkalil Keerthi',
#  'Wang Chen',
#  'Zhang Baopeng',
#  'Woehler J.',
#  'Magini Nicolò',
#  'David Claire',
#  'Rozen Yoram',
#  'Haspeslagh Stefaan',
#  'Pareschi Giovanni',
#  'Fornasier Andrea',
#  'Tulisso Angelica',
#  'Di Piano Ambra',
#  'Warburton Andreas',
#  'Sergeev A.',
#  'Bernardini E.',
#  'Osthelder Charles',
#  'Mashimo Tetsuro',
#  'Capulli Massimo',
#  'Wilms Joern',
#  'Neustroev Vitaly V.',
#  'Sciaccaluga Alberto',
#  'Gualandi Stefano',
#  'Lory Alexander M.',
#  'Molteni Elisabetta',
#  'Desai Chaitra',
#  'Trigger Isabel M.',
#  'Bertelli Matteo',
#  'Drechsler E.',
#  'Panizzolo Roberto',
#  'Martínez Gustavo A.',
#  'Carbognani Franco',
#  'Barone Gaetano',
#  'Laubert Phillip P.',
#  'Wu Yaojun',
#  'Votava Margaret',
#  'Miani Matteo',
#  'Cattaruzza Elti',
#  'Malyukov S.',
#  'Galassi Francesca',
#  'Palazzo Alessandra',
#  'Honan B. P.',
#  'Lai S.',
#  'Petrukhin Alexey',
#  'Kristan Matej',
#  'Zhen Ming',
#  'Grgurina Nataša',
#  'Nakamura Gen',
#  'Michail Dimitrios',
#  'Ortis Lisa',
#  'Tao Zhengcheng',
#  'Blanchinl Franco R.',
#  'Safarzadeh Samani B.',
#  'Xiong Dongliang',
#  'Yoshihara Keisuke',
#  'Olsson Mats Joakim Robert',
#  'Zhulanov Vladimir V.',
#  'Gallardo G. E.',
#  'De Martino Maria',
#  'Shahriar M. Selim',
#  'Valente Riccardo',
#  'Dubois Florent',
#  'Prestegard Tanner',
#  'Tabacco Federica',
#  'Peng Shaogang',
#  'Wengler Thorsten',
#  'Ostachowski Martin Lukas',
#  'Jeanty Laura',
#  'McCarthy Richard',
#  'Goblirsch-Kolb M.',
#  'Rajagopalan S.',
#  'Shehade M.',
#  'Bertoni Cristina',
#  'Wang Wenhao',
#  'Tsiareshka Pavel V.',
#  'Boumediène Djamel Eddine',
#  'Verona C.',
#  'Petrucci Fabrizio',
#  'Di Cristo Michele',
#  'Giacomello Alessandro',
#  'Sorianello Vito',
#  'Bosch-Príncep Ramon',
#  'Quétant Guillaume',
#  'Censi Alberto',
#  'Vernieri Caterina',
#  'Taylor Geoffrey N.',
#  'Lacour D.',
#  'Argos Fernando Carrió',
#  'Jahangirova Gunel',
#  'Zhao Xiaoyun',
#  'Jariwala D.',
#  'Negri A.',
#  'Steinmeyer Daniel',
#  'Picco Raffaella',
#  'Moser Maximilian',
#  'Baba H.',
#  'Peruzzi Elena',
#  'Palazzo Serena',
#  'Dodsworth D.',
#  'Weil Tobias',
#  'Sudhir Vivishek',
#  'Lopez Fernandez B.',
#  'Pilcher J. E.',
#  'Abhayasinghe D. K.',
#  'Hochheim Sven',
#  'Solomon Shalu',
#  'Styles Nicholas A.',
#  'Oreto Cristina',
#  'Montico Marcella',
#  'Mason Michela Cesarina',
#  'Trotta Giacomo',
#  'Goossens Bart',
#  "M'Foukh Adel",
#  'Zhao Qiao',
#  'Gizzi Alessio',
#  'Pizzimento Luca',
#  'Barros Teixeira Mariana G.',
#  'Casanueva Diaz J.',
#  'Ji Xiaozhong',
#  'Votis Konstantinos V.',
#  'Selva Andrea',
#  'Sandoval C.',
#  'Dungs S.',
#  'Pazhuhan Mousa',
#  'Sjölin Jörgen',
#  'Seixas Josem Manoel De',
#  'Novotny R.',
#  'Trivi M. B.',
#  'Yang Wei',
#  'Burleson J.',
#  'Zhang Yueting',
#  'Wendland Björn',
#  'Taglieri Isabella',
#  'García-González María S.',
#  'Gürkan Filiz',
#  'Bruckman de Renstrom P. A.',
#  'Chelikowsky James R.',
#  'Ferrario Viviana',
#  'Salem Mohamed',
#  'Hynek Richard',
#  'Dooley Katherine L.',
#  'Shen Yi',
#  'de Gennaro Michele',
#  'Danninger Matthias',
#  'Roland C. P.A.',
#  'Zhou Yupeng',
#  'Balbo Matteo',
#  'Dupej Peter',
#  'Regazzoni Carlo S.',
#  'Regattieri Alberto',
#  'Chen Chunhui',
#  'Mondal Subhadeep',
#  'Fuster Juan A.',
#  'Austin Corey',
#  'Everson Richard M.',
#  'Goetz R.',
#  'Mikuz̆ Marko',
#  'Chen Yutao',
#  'Liao Qiuyan',
#  'Sattler Torsten',
#  'Zhang Tingyu',
#  'Weinert Michael',
#  'Prinetto Jacopo',
#  'Langenberg Robert J.',
#  'Segata Michele',
#  'Iyer Balar R.',
#  'Belluz Massimo',
#  'Shahinian J. D.',
#  'Pin Davide',
#  'Eynard Davide',
#  'Zhang Tianzhu',
#  'Willocq Stephane',
#  'García Jorge',
#  'Frisch Alain',
#  'Galán D.',
#  'Tonon Federica',
#  'Adam-Bourdarios Claire',
#  'Nikolaou Aristeidis',
#  'Gilbert A. K.',
#  'Rodríguez Vera Ana María',
#  'Perrevoort Ann Kathrin',
#  'Liu Jian',
#  'Schillaci Z. M.',
#  'Seetharaman Guna S.',
#  'Carullo Gregorio',
#  'Cataldi Samuela',
#  'Frezza Mauro',
#  'Liu Chunnian',
#  'Xu Yong',
#  'Saini Shivam',
#  'Geerinck Julie',
#  'Gačnik Dejan',
#  'Wolfe Jaxine',
#  'Vigl Matthias',
#  'Cerny Karel',
#  'Takata Jumpei',
#  'Zhang Ziliang',
#  'Seidl Tobias',
#  'Guidi G. M.',
#  'Kerŝevan Borut Paul',
#  'Mascher Martin',
#  'Tang Jie',
#  'Prokofiev K.',
#  'Nicolaidou Rosy',
#  'Bulmer Richard Hugh',
#  'Graham Kevin',
#  'de Pietro Livia',
#  'Lombardi Mariarosaria',
#  'Zecconi Alfonso',
#  'McMahon Stephen J.',
#  'Puliafito Antonio',
#  'Manicò Giulio',
#  'Pang Peter T.H.',
#  'Chun Seyoung',
#  'Camacho Saritta',
#  'Shirt-Ediss Ben',
#  'Strom Derek A.',
#  'Daniel L.',
#  'Hanuš Jan',
#  'Sgrazzutti Giovanni',
#  'Massa Daniele',
#  'Toppano Sveva',
#  'Kaji Toshiaki',
#  'Cui Wei',
#  'Gessner Gregor',
#  'Digue Albin',
#  'Kurukuru Varaha Satya Bharath',
#  'Kersten Susanne',
#  'Eggebrecht S.',
#  'Mc Gowan J. P.',
#  'Tejus G. K.',
#  'Leardini Chiara',
#  'Choi Seokeon',
#  'Francavilla P.',
#  'Ospanov Rustem',
#  'Rosier-Lees Sylvie',
#  'Lee van Suu A.',
#  'Madonia Alice',
#  'Oliva Francesco Vittadini',
#  'de Lillo N.',
#  'Xiao Liting',
#  'Ungaro F. C.',
#  'Marriott Kim',
#  'de Moura Junior N. M.J.Nunes',
#  'Bussey Peter J.',
#  'Calafiura Paolo',
#  'Veneruso Silvestro V.',
#  'Tschann-Grimm Kathryn',
#  'Bhaskara Vineeth S.',
#  'Li Bing',
#  'Nikiforou Nikiforos',
#  'Brady Michael J.',
#  'Vallier Alexis',
#  'Cucchi Giorgio',
#  'Djama F.',
#  'Zhou Jianqiang',
#  'Min Tianjue',
#  'Ganis Francesco',
#  'Berto Andrea',
#  'Zampieri Gaetano',
#  'Gascuel Olivier',
#  'Schafer Valérie',
#  'Coppolillo Erica',
#  'Venkataraman Subramanian',
#  'Contento Gilberto',
#  'Sbaraglia Marta',
#  'Simonato Manuela',
#  'Gabelli Giovanni',
#  'Acharya B. S.',
#  'Cogo Paola Elisa',
#  'Giancarlo Raffaele',
#  'Llácer María Moreno',
#  'Ameen Nisreen A.',
#  'Basaldella Marco',
#  'Willocq Stéphane Y.',
#  'Ochoa Inês',
#  'Sandri T.',
#  'Lai Stanley T.',
#  'Grampeix Helen',
#  'Betzwieser Joseph C.',
#  'Wall A.',
#  'Suryanarayana P.',
#  'Bertani Roberta',
#  'Zavaroni Carlo',
#  'Cherkaoui Karim',
#  'Lister Alison',
#  'Boscherini Davide',
#  'Cornia Marcella',
#  'Lo Cicero Ugo',
#  'Deng Ruting',
#  'Ewers Lewis Carolyn J.',
#  'Paoletti Riccardo',
#  'Biagioni Chiara',
#  "D'Agostino Simone",
#  'Culpepper J. Shane',
#  'Valent Francesca',
#  'de Luca Federico',
#  'Fafone Viviana',
#  'Thompson Aidan P.',
#  'Gardiman Marina Paola',
#  'Dietrich Tim',
#  'Castillo Florencia L.',
#  'Snidero Matteo',
#  'Tsai M.',
#  'Kulchitsky Yuri A.',
#  'Xingzi Bi',
#  'Canepa Maurizio',
#  'Cavaliere Viviana',
#  'Wang Qi Zhang Qiang',
#  'Navarro Alejandra',
#  'Borg Claudine',
#  'Bondu François',
#  'Galanis Nikolas',
#  'Vassileva Julita',
#  'Yuan M.',
#  'Xiao Zhenggang',
#  'Caggiari Laura',
#  'Watts Gordon T.',
#  'Giovannetti Elio',
#  'Tackmann Kerstin',
#  'Calvet Samuel',
#  'Navarro-Gonzalez J.',
#  'Zhong D.',
#  'Andreazza Attilio',
#  'Benjamin Michael G.',
#  'Tomasi Nicola',
#  'Dong Xingping',
#  'Dinuccio Elio',
#  'Bertetti Massimiliano',
#  'Sciolla G.',
#  'Negrini Matteo',
#  'Marini Padovani Andrea',
#  'Toschi Federico',
#  'Chitarin Giuseppe',
#  'de Piante Marco',
#  'Zhang Lei',
#  'Cheng Yangming',
#  'D’Onofrio Monica',
#  'Albouy Guillaume L.',
#  'Rincke Philipp',
#  'Aranda C. Padilla',
#  'Salvati Daniele',
#  'Singh Harendra Pal',
#  'Teixeira António',
#  'Saturni Francesco Gabriele',
#  'Appelt Christian',
#  'Coromina Lluís Freixas',
#  'Santra Arka',
#  'Caforio Davide',
#  'Bierwagen Katharina',
#  'Stelzer-Chilton Oliver',
#  'Dell’Asta L.',
#  'Dal Mas Francesca',
#  'Sheshi Noel',
#  'Scaboro Simone',
#  'Rokhsar Daniel S.',
#  'Baccarani Giorgio',
#  'Alanko Jarno N.',
#  'Zhao Guodongfang',
#  'Pascoletti Adriano',
#  'Signore Fabrizio',
#  'Man Catherine Nary',
#  'Sala Pietro',
#  'Matichard Fabrice',
#  'de Santo A.',
#  'Bortolussi Luca',
#  'Sykora Tomas',
#  'Eisenstein Robert A.',
#  'Ferreira Tabata Aira',
#  'Hernandez D. Paredes',
#  'Piciarelli Claudio',
#  'Myska Miroslav',
#  'Gambarelli Gianfranco',
#  'Viehhauser Georg H.A.',
#  'Cai Dingding',
#  'Burzynski Jackson Carl',
#  'Wu Mengqing',
#  'Lafratta Anna',
#  'Ferencz Bálint',
#  'Williams Daniel M.',
#  'Weber Christian M.',
#  'Masso-Reid Mariela',
#  'Espert Javier',
#  'Loriette Vincent',
#  'Tatischeff Vincent',
#  'Jeanjean Benoît',
#  'Mareso Chiara',
#  'Mazza Simone Michele',
#  'Maino Giuseppe',
#  'Goorney Simon Richard',
#  'Donini Julien',
#  'Akilli Ece',
#  'Lonardi Stefano',
#  'Dell’Acqua A.',
#  'Wiel C.',
#  'Vargas Maria',
#  'García Alberto',
#  'Gao Jie',
#  'Pezoa Raquel',
#  'Bellentani Laura',
#  'Rifki Othmane',
#  'Vidani Alberto Cabas',
#  'Doria Alessandra',
#  'Spangenberg Martin',
#  'Gambi Alberto',
#  'Mistry Timesh',
#  'Smith T’ai',
#  'Cirillo Italia',
#  'Horii Y.',
#  'Polesello Nello',
#  'Stiglic Gregor',
#  'Fasola Gianpiero P.',
#  'Nelson Kevin',
#  'Pitoni Valentina',
#  'Jang Wonho',
#  'Tarantelli Francesco',
#  'Kingston Jeffrey H.',
#  'Cong Xiaoqing',
#  'Zlatanova Sisi',
#  'Kate Kiran',
#  'Ulloa Poblete P. A.',
#  'Munnini R.',
#  'Kn̈odlseder Jürgen',
#  'Bortolot Martina',
#  'Turgeman Daniel',
#  'Baines John T.M.',
#  'Favre Yannick',
#  'Sivils Kathy L.',
#  'Lan Rushi',
#  'Rinaldi Franca',
#  'Effler Anamaria',
#  'Barták Roman',
#  "D'Onofrio M.",
#  'Ascrizzi Roberta',
#  'Pagano Giulia',
#  'Potter Chris J.',
#  'Carrabino Francesco',
#  'Datrier Laurence Élise Hélène',
#  'Corvaja Pietro',
#  'Bhatta Somadutta',
#  'Vicente-Gómez Noelia',
#  'Riccia Giacomo Della',
#  'Ottino G. J.',
#  'Lombardi Luca',
#  'Someda Carlo Giacomo',
#  'Russo Eleonora',
#  'Rembser Christoph',
#  'Klikovits Stefan',
#  'Vermiglio Rossana',
#  'Rondinella Fabio',
#  'Grimaz Stefano',
#  'Li Z.',
#  'Saibel Andrej',
#  'Hernandez A. C.Romero',
#  'Morley Anthony Keith',
#  'Wang Weizhao',
#  'Leigh Matthew',
#  'Han Yong',
#  'Coletta Paolo',
#  'Rodríguez-González Victor',
#  'Korkmaz Cansu',
#  'Ciobanu Alexei A.',
#  'Vallicella Matteo',
#  'Alper Cem',
#  'Nimier Vincent',
#  'Leonardi Marco',
#  'Santeufemia Davide Adriano',
#  'Ghezzi Carlo',
#  'Ìşsever Cigdem',
#  'Dalla Fontana Giancarlo',
#  'Corteés José Antonio',
#  'Guernieri Gianluca',
#  'Provolo Giorgio',
#  'Pegolo Enrico',
#  'Qi Hong',
#  'Moser Brian',
#  ...]

# %%
autori_matematica = set(
    itertools.chain.from_iterable(
        df_matematica["Author full names"].apply(extract_authors)
    )
)
autori_matematica = list(autori_matematica)
autori_matematica
# Out:
# ['Ciapessoni Emanuele',
#  'Hillert Sonja',
#  'Corriveau François',
#  'Xu Hanlin',
#  'Krückl G.',
#  'Cadoli Marco',
#  'Schmitt N.',
#  'Dollfus Phillippe',
#  'Karas Vladimír',
#  'Fisher Wade C.',
#  'Zimmermann C.',
#  'Hays Jonathan M.',
#  'Rachevski Alexandre',
#  'Loffredo Salvatore',
#  'Oppen H.',
#  'Sultansoy S.',
#  'Zhang Chunhu',
#  'Hemperek Tomasz',
#  'Haug Sigve',
#  'Vogt Marco',
#  'Fodor Zoltán',
#  'Su Jun',
#  'Mohamed A. Tarek Abouelfadl',
#  'Giurgiu Vlad',
#  'Ferri Cesar',
#  'Wyatt T. R.',
#  'Thaele Julia',
#  'Castelo J.',
#  'Muleri Fabio',
#  'Zotta Teresa',
#  'Zolnierowski Yves P.',
#  'Yang Jiawei',
#  'Rizvi E.',
#  'Cannistraci Irene',
#  'Armellini Alessandro',
#  'Marcoccia L.',
#  'Grohs J. P.',
#  'Babal D.',
#  'Kingston M. K.',
#  'Ayling Sarah C.',
#  'Gschwendtner Edda M.',
#  'Tzanakos George S.',
#  'Wittig Tobias',
#  'Nibigira Emery',
#  'Apicella Andrea',
#  'Dingfelder Jochen Christian',
#  'Coccia Simone',
#  'Ivanov Alexander A.',
#  'Yusuff I. M.',
#  'Solans Sanchez Carlos A.',
#  'Okada Shogo',
#  'Padkan Nazanin',
#  'Mastrandrea Paolo',
#  'Coelho Barrue R. F.',
#  'Anderson A. C.',
#  'Lindon Joseph H.',
#  'Lu M.',
#  'Gustavino G.',
#  'Zaghia H.',
#  'Passantino Alessandro',
#  'Duarte-Campderros Jordi',
#  'Loebinger Fred K.',
#  'Song Jiangbo',
#  'Zarrella Angelo',
#  'Ackers M.',
#  'Jones Rhodri O.',
#  'Kiselev Sergey M.',
#  'Montemanni Roberto',
#  'Prast Julie',
#  'Zorbas T. G.',
#  'Gonzalez Silva M. L.',
#  'Göttfert T.',
#  'Walker S. D.',
#  'Pastor O. Estrada',
#  'Brunner Kristóf M.',
#  'Liu M. Y.',
#  'Barazza Fausto',
#  'Torelli Lucio',
#  'Petousis Vlasios',
#  'Kondrashova Nataliia',
#  'Zavada Petr',
#  'Mahlstedt J.',
#  'Mikuaz M.',
#  'Tanskanen Jaakko A.',
#  'Elmasri Ramez A.',
#  'He Xiangyu',
#  'Urbán Jozef',
#  'Maekawa Koki',
#  'Nielsen Bae Svane',
#  'Favareto Andrea',
#  'Marini Marco Raoul',
#  'Ballabene E.',
#  'Guo Di',
#  'Barkeloo Jason T.',
#  'Freire Rodrigo A.',
#  'Lara V.',
#  'Martin Ph',
#  'Mindur B.',
#  'Connell Simon H.',
#  'Azoulay A. M.',
#  'Qualizza Andrea',
#  'Vigani Luigi',
#  'Bruni Roberto',
#  'Potti H.',
#  'Vazquez Furelos D.',
#  'Sanfilippo L.',
#  'Dobre Monica',
#  'Abela Kevin',
#  'Silberberg C. Deluca',
#  'Leis U.',
#  'Delgado J.',
#  'Diglio Sara',
#  'Gruwé Magali',
#  'Sieg Wilfried',
#  'Zaitsev Alexander M.',
#  'Faszer Wayne',
#  'Gnani Dario',
#  'Wiebe Klaus',
#  'del Prete Tarcisio',
#  'Torii Hisayuki A.',
#  'Will Sebastian',
#  'Wang Liang',
#  'Frigerio Alberto',
#  'Ferrari Carlo',
#  'Falda Ulhoa Coelho L. F.',
#  'Li Huaishen',
#  'Groth Marco',
#  'Levêque Jessica',
#  'Girotti Paolo',
#  'Graber L.',
#  'Blondel Alain P.',
#  'Bate R.',
#  'Scarfó Giuseppe',
#  'Asinari Pietro',
#  'Schwemling Ph',
#  'Sullivan M. J.',
#  'Munday David J.',
#  'Schoerner T.',
#  'Karkout Osama',
#  'Murray Peter',
#  'Marchese Luigi',
#  'Leney Katharine J.C.',
#  'Risti’C Branislav',
#  'Ceterchi Rodica',
#  'Libralato Michele',
#  'Molinari Alberto',
#  'Mukherjee Reshmi',
#  'Toale P. A.',
#  'Tosciri Cecilia',
#  'Costanzo Davide',
#  'Fanti Marcello',
#  'Garelli Nicoletta',
#  'Cross Robert M.',
#  'Cap Sebastien',
#  'Hauptmann Alexander Georg',
#  'Miele Paola',
#  'Diblen F.',
#  'Edgar R. C.',
#  'Amoroso Simone',
#  'Cleland B.',
#  'Wu Chao',
#  'Di Luca Massimiliano',
#  'Barisonzi M.',
#  'Spanó F.',
#  'Hetmánek M.',
#  'Prasad S.',
#  'Becherer F.',
#  'Nievas-Rosillo M.',
#  'Beretta Edoardo',
#  'Yu.Sviridov M.',
#  'Luvisetto M. L.',
#  'Diaz Capriles F. G.',
#  'Jia Xiaoqian',
#  'Diehl Roland D.',
#  'Boosten Marcel',
#  'Montangero Carlo',
#  'Guerrieri Antonio',
#  'Huang Qiushi',
#  'Cordero Francesca',
#  'Hod Noam Tal',
#  'Hill Christopher S.',
#  'Zweig Katharina A.',
#  'Gutierrez Ortiz N. G.',
#  'Hutter Dirk',
#  'Castiglioni Valentina',
#  'Tydesjö H.',
#  'Pittaro-Cadore Italo',
#  'Hamal P.',
#  'Kemkes Philipp',
#  'Zeng Hao',
#  'Giraudo Giuseppe',
#  'Hoffmann Hans Falk',
#  'Bansal Sunil',
#  'van Bulck David',
#  'Cristinziani M.',
#  'Engels A. Arbet',
#  'Santamarina Ŕos Cibrán',
#  'Hadash E.',
#  'Biswas Diptaparna',
#  'Tokushuku Katsuo',
#  'Weber Marc',
#  'Röhrich Dieter',
#  'Bianco Gianluca',
#  'Semple Charles',
#  'Hanabata Yoshitaka',
#  'Symons Timothy J.M.',
#  'Adam Lennart',
#  'Luci Claudio',
#  'Ferland J.',
#  'Rauter E.',
#  'Onogi Kouta',
#  'Stonjek Stefan',
#  'Gargiulo S.',
#  'Rosa Giovanni La',
#  'Ambrosi Giovanni',
#  'Law Mark',
#  'Rapisarda Massimo',
#  'Bernini Federico',
#  'Di Gennaro Roberta',
#  'Mori Toshinori',
#  'Catelan Dolores',
#  'Damiani Daniel S.',
#  'Youssef Saul P.',
#  'Kraus A. C.',
#  'Nag Nag A.',
#  'Newhouse Robin',
#  'Brooijmans Gustaaf',
#  'Celli Michele',
#  'Martinez-Suarez Paula',
#  'Wolf T. M.H.',
#  'Coppola Paolo',
#  'Beemster L. J.',
#  'Burghgrave Blake',
#  'Sire Yannick',
#  'Richman Michael S.',
#  'Aulchenko Vladimir M.',
#  'Aurousseau Mathieu',
#  'Allen J. S.',
#  'Aricò Antonino Salvatore',
#  'Matakias D.',
#  'Simonin Olivier',
#  'Salibra Antonino',
#  'Stegler M.',
#  'Guigó Roderic',
#  'Grohs J. Philipp',
#  'Kolevatov Rodion S.',
#  'Mochizuki Ai',
#  'Moriarty P.',
#  'Fokin Sergey L.',
#  'Sandaker Heidi',
#  'Song Zhaoliang',
#  'Reich Alexander',
#  'Stefanini Giorgio',
#  'Tokanai Fuyuki',
#  'Hesketh Gavin G.',
#  'Dzhafarov Damir D.',
#  'Cranshaw Jack M.',
#  'Gallas Elizabeth J.',
#  'Cacchiani Valentina',
#  'Moulai Marjon H.',
#  'Console Luca',
#  'Esseni David',
#  'Huettmann A.',
#  'Yang Hongtao T.',
#  'Russo Gaetano',
#  'Fisher S. M.',
#  'Yan S.',
#  'Maggiolo-Schettin Andrea',
#  'Volpe Giacomo',
#  'Guidorzi Cristiano',
#  'Takeda Yukio',
#  'Barone-Netto Angelo',
#  'Otec Roman',
#  'Bingefors Nils',
#  'Roberts R. T.',
#  'Maniezzo Vittorio',
#  'Perantoni M.',
#  'Chang Beomsu',
#  'Akiyama Daiya',
#  'Kluge Alexander',
#  'Rossi Lidia',
#  'Abdari Ali',
#  'Papadopoulou Th D.D.',
#  'Hrupec Dario',
#  'Hubaut Fabrice',
#  'Lamanna E.',
#  'Penzin Maksim S.',
#  'Pagan-Griso Simone',
#  'Gorini Benedetto',
#  'Sanchez L. R.',
#  'Hedderman Paul',
#  'Kouyoumdjian D. F.',
#  'Kushida Junko',
#  'Hamer Matthias',
#  'Etienvre I.',
#  'Aikot Aravind',
#  'Bresolin Davide',
#  'Moore Jason R.',
#  'Rawlins Katherine',
#  'Klein Max H.',
#  'Buanes Trygve',
#  'Røhne Ole Myren',
#  'Mergelmeyer Sebastian',
#  'Miyazaki Tsuyoshi',
#  'Huang F.',
#  'Balek Petr',
#  'Yamatani M.',
#  'Hu X.',
#  'De Gruttola Daniele',
#  'Bruers Ben',
#  'Supra Joshua',
#  'Kox Serge',
#  'Morisbak Vanja',
#  'Feltrin Guglielmo',
#  'McCann Andrew J.',
#  'Ercolessi Furio',
#  'Denisov Sergey P.',
#  'Barashkou A.',
#  'Gambella F.',
#  'Hyneman R.',
#  'Arutinov David',
#  'Dubuisson J.',
#  'Albicocco Pietro',
#  'Bercuci Alexandru',
#  'Michelotto Michele',
#  'Bhimji Wahid',
#  'Das Abir',
#  'Dijacki J.',
#  'Mann W. Anthony',
#  'Huang S.',
#  'Huson Daniel H.',
#  'Cooke Michael P.',
#  'Tholen Walter',
#  'Martinez Agullo P.',
#  'Ferro Federico',
#  'Wang H.',
#  'Di Ruzza Benedetto',
#  'Hirose Minoru',
#  'Cavalleri Pietro G.',
#  'Zorzetto Dafne',
#  'Linhart Vladimír',
#  'Werthenbach Ulrich',
#  'Wiese A.',
#  'Grillo Gabriele',
#  'Bruni Marco',
#  'Ruli Erlis',
#  'Waugh Benedict M.',
#  'Franco Luca',
#  'Tsybychev D.',
#  'Kosmidis Ioannis',
#  'Park Woochun',
#  'Salvachua-Ferrando Belen M.',
#  'Baruzzo Marco',
#  'Bianco Michele',
#  'Zheng S.',
#  'Rothberg Joseph E.',
#  'Perera Viraj J.O.',
#  'Verdeil Alexandra',
#  'Gerashchenko Sergiy',
#  'Dehchar D.',
#  'Fomichev I.',
#  'Webb A. F.',
#  'Virgili Andrea',
#  'Orsini Fabienne',
#  'Gity Farzan',
#  'Gibbons Lawrence K.',
#  'Rissone Paolo',
#  'Jones Matthew A.',
#  'Ostrega Maciej S.',
#  'Lin K.',
#  'Allbrooke B. M.M.',
#  'Leung H. K.',
#  'Fasching Damon',
#  'Guzik Marcin P.',
#  'Young N. D.',
#  'Vitti Stefano',
#  'Klein-Bösing Christian',
#  'Sciarrone Giulia',
#  'Bueso Xavier Portell',
#  'Kuhl Andrew',
#  'Yi Jungyu',
#  'Carpentieri Carmen',
#  'Tonazzo Alessandra',
#  'Clamer Valentina',
#  'Richards E.',
#  'van Vleck Erik S.',
#  'Sadrozinski Hartmut F.W.',
#  'Faivre Julien Cl',
#  'Honseil Furio',
#  'Lutz J. R.',
#  'Caviedes Betancourt L. J.',
#  'Tornambe P.',
#  'Mohrdieck-Möck Susanne M.',
#  'Ŝimák Vladislav',
#  'Ferrara V.',
#  'Karimov Artur I.',
#  'Giorgi Filippo Maria',
#  'Meli Antonella',
#  'Tskhadadze Edisher G.',
#  'Torrente Yvan',
#  'Gugel R.',
#  'Altinpinar Sedat',
#  'Mucelli Raffaella Pozzi',
#  'Sykora Martin',
#  'Fitzgerald E. A.',
#  'Bezshyiko Iaroslava',
#  'Grenier Isabelle A.',
#  'Koch Simon Florian',
#  'Menegolli Alessandro',
#  'Stamenkovic Marko',
#  'Zanato Massimiliano',
#  'Martínez Mario',
#  'Principe Giacomo',
#  'Tobon Cesar Augusto Marin',
#  'Ritacco Ettore',
#  'Senthilkumar V.',
#  'Takubo Yosuke',
#  'Singh Sukhman',
#  'Caracinha Diogo',
#  'Gardner Robert William',
#  'Solis L. A.',
#  'De Luca Ernesto William',
#  'Guedel Manuel',
#  'Carvalho Joao C.L.',
#  'Cox J.',
#  'Burden Annette',
#  'Zhang X.',
#  'Gispert Maria A.',
#  'Egidi Lavinia',
#  'Miller R. J.Dwayne',
#  'George Simon',
#  'Hulsbergen Wouter D.',
#  'Degrange Jordan',
#  'Panitkin Sergey Yu',
#  'Wills Lise',
#  'Wu X.',
#  'Schouwenberg J. F.P.',
#  'Bauce Matteo',
#  'Slanina Matteo',
#  'Rädel Leif',
#  'Yorita Kohei',
#  'Shimizu S.',
#  'Zancola Andrea',
#  'Lu Nan',
#  'Maiboroda Vera',
#  'Vande Voorde U. M.',
#  'Marques João Lourenço',
#  'Redamalla Rekha',
#  'Basmanov Valery F.',
#  'Baumann Christoph Heinrich',
#  'Mahmoud Saida Saad Mohamed',
#  'Zavattaro Gianluigi',
#  'Zonca Eric',
#  'Campagna Francesco',
#  'Karpova Z. M.',
#  'Černčič Eva',
#  'McNamara Peter Charles',
#  'Suzuki Yoshihiro',
#  'Mahout Gilles',
#  'Brooks E. M.',
#  'Giromini P.',
#  'Sabatini Fabrizio S.',
#  'la Rocca Gevisa',
#  'Shafer Paul',
#  'Averbeck Ralf Peter',
#  'Migliaccio A.',
#  'Silva Ferreira I.',
#  'Gouighri M.',
#  'Corpe Louie Dartmoor',
#  'Chelkov Georgy A.',
#  'Rompotis Nikolaos',
#  'Lavery Paul S.',
#  'da Costa João Barreiro Guimarães',
#  'Schade Robert',
#  'Hance Mike',
#  'Chiantini L.',
#  'Pelant Jan',
#  'Choo Jiyeon',
#  'Huang X.',
#  'Kar Payel',
#  'Hubramania S.',
#  'Langrekken O. K.B.',
#  'Santini Carolina',
#  'Celebi Emre',
#  'Chiţan Adrian',
#  'Teixeira.dias.castanheira M.',
#  'Kortsarz Guy',
#  'Ploskoń Mateusz Andrzej',
#  'Rodà Antonio',
#  'Giusti Christian',
#  'Radhakrishnan Sooraj K.',
#  'Borel Herve',
#  'Val’a Martin',
#  'von Radziewski H.',
#  'Abovyan Sergey',
#  'McClymont L. I.',
#  'Mondal Spandan',
#  'Montella Alessandro',
#  'Codognato Giulio',
#  'Kleinknècht Konrad',
#  'Muse J. M.',
#  'Menegon Davide',
#  'Thielmann O.',
#  'Kilvington G.',
#  'Suárez-Vargas José J.',
#  'Peiffer Peter',
#  'Delogu C. C.',
#  'Liu Hongbin',
#  'Jiang Yan',
#  'Protopopescu Serban D.',
#  'Sauve R. M.',
#  'Moreno Perez J. M.',
#  'Scheffler Matthias',
#  'Vichou I.',
#  'McPherson Robert A.',
#  'Yamaguchi Daiki',
#  'Ghodbane Nabil',
#  'Rosten J. H.N.',
#  'Pagano Paola',
#  'Carter T. M.',
#  'Gkountoumis Panagiotis',
#  'Mohrmann Lars',
#  'Oreglia M. J.',
#  'Hallewell Gregory D.',
#  'Weber Michele S.',
#  'Cornaro Cristina',
#  'Geng C.',
#  'Gagnon Louis Guillaume',
#  'Ciecko R. P.',
#  'Scapin Emanuele',
#  'Jakobs Karl',
#  'Tibbetts Mark J.',
#  'Nallet Franck',
#  'Thornberry R. E.',
#  'Marsh Ben',
#  'Navarro Laura Barranco',
#  'Poddar S.',
#  'Kawaguchi Y.',
#  'Maguire Helen',
#  'Fonseca Giovanni',
#  'Westby Per H.',
#  'Dumancic Mirta',
#  'Traczyk Tomasz',
#  'Kenne Pagui Euloge Clovis',
#  'Stepanov Eugene O.',
#  'Fan Cunwei',
#  'Agatonović-Jovin T.',
#  'Antonescu Mihai',
#  'Hoffmann A. E.',
#  'Elldge D.',
#  'Tian Y.',
#  'Boline Daniel D.',
#  'Miyazaki Y.',
#  'Gorïek A.',
#  'Hong Tae-min',
#  'Burton Charles D.',
#  'Toraldo Gerardo',
#  'Orellana G. E.',
#  'Binet S.',
#  'Istrail Sorin C.',
#  'Sala Alessandro',
#  'Cabodi Gianpiero',
#  'Wienemann Peter',
#  'Ludwig A.',
#  'Duncan Anna K.',
#  'Standke Mark',
#  'Soffer Abner',
#  'Pang Hao',
#  'Gaẑo Emil',
#  'Lu Wei',
#  'Kim D. W.',
#  'Tavecchio Fabrizio',
#  'Hangal Dhanush Anil',
#  'Morinaga Masahiro',
#  'Iori M.',
#  'Chevallier Florent',
#  'Hoffman Kara D.',
#  'Pirani Alessandro',
#  'Arguëlles Jonito Aerts',
#  'Nakkalil Keerthi',
#  'Wang Chen',
#  'Goldschmidt Azriel',
#  'Booth C. N.',
#  'Greenshaw Timothy J.',
#  'David Claire',
#  'Rozen Yoram',
#  'Kroll Mike',
#  'Pareschi Giovanni',
#  'Hicks Patrick',
#  'Fornasier Andrea',
#  'Bastid Nicole',
#  'Hu M.',
#  'Di Piano Ambra',
#  'Campana G.',
#  'Åkerstedt Henrik',
#  'Warburton Andreas',
#  'Paravano Cristian',
#  'Reece Ryan D.',
#  'Bernardini E.',
#  'Mashimo Tetsuro',
#  'Singh Ranbir',
#  'Drakhlin Michael E.',
#  'Wilms Joern',
#  'Szostak Artur Krzysztof',
#  'Neustroev Vitaly V.',
#  'Sciaccaluga Alberto',
#  'Klier Amit',
#  'Gualandi Stefano',
#  'Lory Alexander M.',
#  'Bach Matthias Jakob',
#  'Yuan L.',
#  'Pina J.',
#  'Trigger Isabel M.',
#  'Ryabov Yu F.',
#  'Drechsler E.',
#  'Zanzottera Riccardo',
#  'Han Shuang',
#  'Moorhead Gareth F.',
#  'Martínez Gustavo A.',
#  'Vikhlyantsev Oleg V.',
#  'Jackson James',
#  'Barone Gaetano',
#  'Laubert Phillip P.',
#  'Wu Yaojun',
#  'Jansen L.',
#  'Disset Gael',
#  'Li H. L.',
#  'Yajima K.',
#  'Popović Dragan S.',
#  'Malyukov S.',
#  'Auffenberg Jan',
#  'Graaf H. Van Der',
#  'Honan B. P.',
#  'Palazzo Alessandra',
#  'Lai S.',
#  'Petrukhin Alexey',
#  'Kristan Matej',
#  'Chojnacki Marek',
#  'Nakamura Gen',
#  'Delagrange Hugues',
#  'Michail Dimitrios',
#  'Ninomiya Yoichi',
#  'Tao Zhengcheng',
#  'Schiaua Claudiu Cornel',
#  'Jones James Kevin',
#  'Safarzadeh Samani B.',
#  'Xiong Dongliang',
#  'Soares Mara Senghi',
#  'Yoshihara Keisuke',
#  'Ernwein J.',
#  'Olsson Mats Joakim Robert',
#  'Zhang J.',
#  'Zhulanov Vladimir V.',
#  'Gallardo G. E.',
#  'Dubois Florent',
#  'Peng Shaogang',
#  'Wengler Thorsten',
#  'Sun Quan',
#  'Jeanty Laura',
#  'Russo Francesco G.',
#  'Goblirsch-Kolb M.',
#  'Bruzzo Ugo',
#  'Rajagopalan S.',
#  'Lodhi Eesha',
#  'Shehade M.',
#  'Wang Wenhao',
#  'Tsiareshka Pavel V.',
#  'Boumediène Djamel Eddine',
#  'Rafí Joan Marc',
#  'Petrucci Fabrizio',
#  'Di Cristo Michele',
#  'Madagodahettige-Don Dilan Minthaka',
#  'Bosch-Príncep Ramon',
#  'Quétant Guillaume',
#  'Vives R.',
#  'Vernieri Caterina',
#  'Taylor Geoffrey N.',
#  'Lacour D.',
#  'Pitman Donaldson C.',
#  'Zhao Xiaoyun',
#  'Peresunko Dmitri',
#  'Baba H.',
#  'Negri A.',
#  'Stolfa Andrea',
#  'Salce Luigi',
#  'Hirsemann Helmut',
#  'Palazzo Serena',
#  'Dodsworth D.',
#  'Mikenberg Giora',
#  'Lopez Fernandez B.',
#  'Lupu Nachman Z.',
#  'Pilcher J. E.',
#  'Abhayasinghe D. K.',
#  'Solomon Shalu',
#  'Styles Nicholas A.',
#  'Ilkiv Iryna M.',
#  'Miró-Roig Rosa María María',
#  'Moloney Glenn R.',
#  'Trotta Giacomo',
#  "M'Foukh Adel",
#  'Zhao Qiao',
#  'Gizzi Alessio',
#  'Hansen Johnny Renner',
#  'Sevcenco Adrian',
#  'Barros Teixeira Mariana G.',
#  'Pizzimento Luca',
#  'Iwański Wieslaw',
#  'Hartert J.',
#  'Ghosh Premomoy S.',
#  'Antonioli Pietro',
#  'Aparisi Pozo J. A.',
#  'Sandoval C.',
#  'Dungs S.',
#  'Snellings Raimond J.M.',
#  'Novotny R.',
#  'Seixas Josem Manoel De',
#  'Sjölin Jörgen',
#  'De La Taille Christophe H.',
#  'Baker Keith',
#  'Copeta Alessandro',
#  'Piana Edoardo Alessio',
#  'Burleson J.',
#  'Ennis J. S.',
#  'Zhang Yueting',
#  'Bevilacqua Roberto',
#  'Wendland Björn',
#  'Perez S. Fernandez',
#  'Ponsot Patrick',
#  'Bruckman de Renstrom P. A.',
#  'Gareau M.',
#  'Cristofori Alessandro',
#  'Chelikowsky James R.',
#  'Hynek Richard',
#  'de Gennaro Michele',
#  'Shen Yi',
#  'Danninger Matthias',
#  'Seltmann Jörn',
#  'Roland C. P.A.',
#  'Zhou Yupeng',
#  'Balbo Matteo',
#  'King Matthew G.L.',
#  'Caldiroli Paolo',
#  'Regazzoni Carlo S.',
#  'Chen Chunhui',
#  'Fajardo L. S.Gomez',
#  'Mondal Subhadeep',
#  'Kuerten J. G.M.',
#  'Fuster Juan A.',
#  'Žsenei A.',
#  'Mikuz̆ Marko',
#  'Chen Yutao',
#  'Liao Qiuyan',
#  'Lin Simon C.',
#  'Zhang Tingyu',
#  'Prinetto Jacopo',
#  'Maneira Manuel J.P.',
#  'Pestov Yury N.',
#  'Schorlemmer A. L.S.',
#  'Mangin-Brinet Mariane',
#  'Délemontex T.',
#  'Langenberg Robert J.',
#  'Smith Kenway M.',
#  'Salazar Loyola J. E.',
#  'Maggi Valter',
#  'Shahinian J. D.',
#  'Jackson N.',
#  'Zhang Tianzhu',
#  'Willocq Stephane',
#  'Frisch Alain',
#  'Galán D.',
#  'Abeyaratne Rohan C.',
#  'Cornelissen Thijs G.',
#  'Adam-Bourdarios Claire',
#  'Doherty Thomas',
#  'Gilbert A. K.',
#  'Lösel Philipp J.',
#  'Mayri Christophe',
#  'Rodríguez Vera Ana María',
#  'Perrevoort Ann Kathrin',
#  'Habashi Wagdi George',
#  'Schillaci Z. M.',
#  'Petris Mariana',
#  'Seetharaman Guna S.',
#  'Helbing Klaus',
#  'Booth J. R.A.',
#  'Liu Chunnian',
#  'Xu Yong',
#  'Degele Reinhold',
#  'Monarca Umberto',
#  'Gačnik Dejan',
#  'Pancake Charles E.',
#  'Conrad Janet M.',
#  'Wolfe Jaxine',
#  'Weinstein Amanda',
#  'Guttman Nir',
#  'Cerny Karel',
#  'Vigl Matthias',
#  'Takata Jumpei',
#  'Zhang Ziliang',
#  'Gabbanini C.',
#  'Miao J.',
#  'Arnaud Michel',
#  'Wijeratne P. A.',
#  'Suchkov Sergey I.',
#  'Kerŝevan Borut Paul',
#  'Mascher Martin',
#  'Tang Jie',
#  'Prokofiev K.',
#  'Nicolaidou Rosy',
#  'Bulmer Richard Hugh',
#  'Cormier Kyle J.R.',
#  'Graham Kevin',
#  'Della Monica E.',
#  'McMahon Stephen J.',
#  'La Barbera Antonino',
#  'Di Santo Raffaele',
#  'Manicò Giulio',
#  'Troncon Clara',
#  'Camacho Saritta',
#  'Serenari Matteo',
#  'Strom Derek A.',
#  'Daniel L.',
#  'Cioar I. A.',
#  'Kaji Toshiaki',
#  'Pedis D. De',
#  'Béteille André',
#  'Liessi Davide',
#  'Cui Wei',
#  'Gessner Gregor',
#  'Digue Albin',
#  'Hartjes Fred G.',
#  'Colavitto Erik',
#  'Kersten Susanne',
#  'Eggebrecht S.',
#  'Mc Gowan J. P.',
#  'Okumura K.',
#  'Choi Seokeon',
#  'Francavilla P.',
#  'Ospanov Rustem',
#  'Rosier-Lees Sylvie',
#  'Perissutti Diego',
#  'Klein Spencer R.',
#  'Schoening André',
#  'de Lorenzi Francesco',
#  'Madonia Alice',
#  'Cascella Michele',
#  'Betev Latchezar L.',
#  'Skinnari Louise A.',
#  'Bossú Francesco',
#  'Zhang K.',
#  'Ungaro F. C.',
#  'Badri Sahar',
#  'Ducroux Laurent',
#  'Axen B.',
#  'Marriott Kim',
#  'Mazza G.',
#  'Bussey Peter J.',
#  'Calafiura Paolo',
#  'Devia Carlos Andrés',
#  'Tschann-Grimm Kathryn',
#  'Bhaskara Vineeth S.',
#  'El Moussaouy Abderrahim L.',
#  'Nikiforou Nikiforos',
#  'Li Bing',
#  'Vallier Alexis',
#  'Bourlis George',
#  'Andretta Alessandro',
#  'Djama F.',
#  'Brady Michael J.',
#  'Min Tianjue',
#  'Losco Luigi',
#  'Zampieri Gaetano',
#  'Gascuel Olivier',
#  'Coppolillo Erica',
#  'Kesson A.',
#  'Venkataraman Subramanian',
#  'Gabelli Giovanni',
#  'Acharya B. S.',
#  'Pickering Mark A.',
#  'Fokitis M.',
#  'Sahoo Raghunth K.',
#  'Dos Santos M. A.Pimenta',
#  'Bessudo Ilan',
#  'Giancarlo Raffaele',
#  'Basaldella Marco',
#  'Gallas Torreira M. V.',
#  'Willocq Stéphane Y.',
#  'Jérémie Andrea',
#  'Vannucci Luigi',
#  'Ge P. S.',
#  'Ochoa Inês',
#  'Pachr Milos',
#  'Hartung P.',
#  'Bustos A. C.Florez',
#  'Lai Stanley T.',
#  'Arsene Ionut Cristian',
#  'Peters Andreas Joachim',
#  'Ludwig Inga',
#  'Franchino Silvia',
#  'Lewis Wayne',
#  'Castillo Castellanos Javier Ernesto',
#  'Einecke Sabrina',
#  'Wall A.',
#  'Suryanarayana P.',
#  'Manning P. M.',
#  'Kellermann E.',
#  'Turcati Andrea',
#  'Ivanov Marian',
#  'Zavaroni Carlo',
#  'Cherkaoui Karim',
#  'Kanaya Naoko',
#  'Lister Alison',
#  'von Loeben Jörg',
#  'Lu Liang',
#  'Boscherini Davide',
#  'Comfort William Wistar',
#  'Labbé J. A.',
#  'Lo Cicero Ugo',
#  'Boyer Bruno Alexandre',
#  'Ewers Lewis Carolyn J.',
#  'Paoletti Riccardo',
#  'Maaen M.',
#  'Skaali Toralf Bernhard',
#  'Culpepper J. Shane',
#  'Valent Francesca',
#  'Thompson Aidan P.',
#  'Saito M.',
#  'Beattie M. D.',
#  'Castillo Florencia L.',
#  'Komori Y.',
#  'Tsai M.',
#  'Kulchitsky Yuri A.',
#  'Xingzi Bi',
#  'Boscaggin Alberto',
#  'Serradilla Eulogio',
#  'Eklund M.',
#  'Lambert Fabian',
#  'Cavaliere Viviana',
#  'Vassileva Julita',
#  'Borg Claudine',
#  'Voloshin Kirill G.',
#  'Ferro Fabrizio',
#  'Yuan M.',
#  'Hervet Olivier',
#  'Das Supriya',
#  'Watts Gordon T.',
#  'Giovannetti Elio',
#  'Tackmann Kerstin',
#  'Calvet Samuel',
#  'Navarro-Gonzalez J.',
#  'Andreazza Attilio',
#  'Zhong D.',
#  'Savic Natascha',
#  'Golonka Piotr J.',
#  'Tomasi Nicola',
#  'Salvati Silvana Carla',
#  'Tessarolo Alberto',
#  'Sciolla G.',
#  'Negrini Matteo',
#  'Marini Padovani Andrea',
#  'Toschi Federico',
#  'Espagnon Bruno',
#  'Chitarin Giuseppe',
#  'King S. B.',
#  'Zhang Lei',
#  'Cheng Yangming',
#  'D’Onofrio Monica',
#  'Gorfine Grant W.',
#  'Albouy Guillaume L.',
#  'Atkinson T. M.',
#  'Parrish E. W.P.',
#  'Rincke Philipp',
#  'Aranda C. Padilla',
#  'Xie Song',
#  'Salvati Daniele',
#  'Steffens J. L.',
#  'Rudolph Gerald',
#  'Limosani Antonio',
#  'Saturni Francesco Gabriele',
#  'Appelt Christian',
#  'Coromina Lluís Freixas',
#  'Suzuki Y.',
#  'Seghieri Chiara',
#  'Santra Arka',
#  'Caforio Davide',
#  'Bierwagen Katharina',
#  'Stelzer-Chilton Oliver',
#  'Dell’Asta L.',
#  'González Sergio',
#  'Nikolaev S. A.',
#  'Scaboro Simone',
#  'Alanko Jarno N.',
#  'Tompkins Daniel',
#  'Pascoletti Adriano',
#  'Tarek Abouelfadl A. Mohamed',
#  'Sala Pietro',
#  'de Santo A.',
#  'Bortolussi Luca',
#  'Sykora Tomas',
#  'Hernandez D. Paredes',
#  ...]

# %% [markdown]
# <h3>Lista degli autori degli articoli di informatica che sono anche professori</h3>

# %%
autori_professori_inf = []

for author in autori_informatica:
    if author in professori_informatica:
        autori_professori_inf.append(author)
autori_professori_inf.sort()        

print(autori_professori_inf)
# Out:
# ['Bozzo Enrico', 'Brajnik Giorgio', 'Burigat Stefano', 'Buttussi Fabio', 'Chittaro Luca', 'Cimatti Alessandro', 'Comini Marco', 'Coppola Paolo', 'Dattolo Antonina', 'Della Mea Vincenzo', 'Della Monica Dario', 'Di Gianantonio Pietro', 'Dovier Agostino', 'Drioli Carlo', 'D’Agostino Giovanna', 'Fogolari Federico', 'Fontana Federico', 'Formisano Andrea', 'Fortuna Sara', 'Franceschet Massimo', 'Fusiello Andrea', 'Geatti Luca', 'Lenisa Marina', 'Maddalena Eddy', 'Mameli Valentina', 'Micheloni Christian', 'Miculan Marino', 'Mirolo Claudio', 'Mizzaro Stefano', 'Montanari Angelo', 'Omero Paolo', 'Piazza Carla', 'Policriti Alberto', 'Puppis Gabriele', 'Riccio Vincenzo', 'Ritacco Ettore', 'Roitero Kevin', 'Scagnetto Ivan', 'Serra Giuseppe', 'Vermiglio Rossana', 'Vidoni Paolo']

# %% [markdown]
# <h3>Lista degli autori degli articoli di matematica che sono professori di informatica</h3>

# %%
autori_professori_mat_inf = []
for author in autori_matematica:
    if author in professori_informatica:
        autori_professori_mat_inf.append(author)
autori_professori_mat_inf.sort()
print(autori_professori_mat_inf)
# Out:
# ['Bellettini Giovanni', 'Bozzo Enrico', 'Brajnik Giorgio', 'Burigat Stefano', 'Buttussi Fabio', 'Chittaro Luca', 'Cimatti Alessandro', 'Comini Marco', 'Coppola Paolo', 'Dattolo Antonina', 'Della Mea Vincenzo', 'Della Monica Dario', 'Di Gianantonio Pietro', 'Dimonte Vincenzo', 'Dovier Agostino', 'Drioli Carlo', 'D’Agostino Giovanna', 'Fogolari Federico', 'Fontana Federico', 'Formisano Andrea', 'Fortuna Sara', 'Franceschet Massimo', 'Fusiello Andrea', 'Geatti Luca', 'Lenisa Marina', 'Liessi Davide', 'Maddalena Eddy', 'Mameli Valentina', 'Micheloni Christian', 'Miculan Marino', 'Mirolo Claudio', 'Mizzaro Stefano', 'Montanari Angelo', 'Pace Luigi', 'Piazza Carla', 'Policriti Alberto', 'Puppis Gabriele', 'Riccio Vincenzo', 'Ritacco Ettore', 'Roitero Kevin', 'Romani Giulio', 'Scagnetto Ivan', 'Serra Giuseppe', 'Vermiglio Rossana', 'Vidoni Paolo']

# %% [markdown]
# <h3>Professori di informatica che non sono presenti tra gli autori di articoli di matematica</h3>

# %%
'''
professori_inf_non_in_mat = []

for author in autori_professori_inf:
    if author not in autori_professori_mat_inf:
        professori_inf_non_in_mat.append(author)
professori_inf_non_in_mat.sort()

print(professori_inf_non_in_mat)
'''
# Out:
# '\nprofessori_inf_non_in_mat = []\n\nfor author in autori_professori_inf:\n    if author not in autori_professori_mat_inf:\n        professori_inf_non_in_mat.append(author)\nprofessori_inf_non_in_mat.sort()\n\nprint(professori_inf_non_in_mat)\n'

# %%
professori_inf_non_in_mat = []

for author in professori_informatica:
    if author not in autori_professori_mat_inf:
        professori_inf_non_in_mat.append(author)
professori_inf_non_in_mat.sort()

print(professori_inf_non_in_mat)
# Out:
# ['Lancia Giuseppe', 'Omero Paolo']

# %% [markdown]
# <h1>Grafico del numero di articoli per professori di informatica</h1>

# %%
conteggio_articoli_informatica = Counter()

for autori_str in df_informatica["Author full names"]:
    autori_inf = extract_authors(autori_str)
    for a in autori_inf:
        if a in professori_informatica:   # match professori
            conteggio_articoli_informatica[a] += 1

# %%
df_professori_articoli = pd.DataFrame(
    conteggio_articoli_informatica.items(),
    columns=["Professore", "Numero articoli"]
)

# %%
df_professori_articoli.sort_values("Numero articoli").plot(
    x="Professore", y="Numero articoli", kind="barh", figsize=(8,10)
)

plt.title("Numero di articoli per professore (Informatica)")
plt.xlabel("Articoli")
plt.ylabel("Professore")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Grafo delle Coauthorship</h1>

# %%
def parse_authors(author_string):
    if pd.isna(author_string):
        return []
    chunks = [x.strip() for x in author_string.split(';')]
    authors = []
    for c in chunks:
        match = re.match(r"([^,]+),\s*([^(]+)", c)
        if match:
            cognome = match.group(1).strip()
            nome = match.group(2).strip()
            authors.append(f"{cognome} {nome}")
    return authors

df = df_informatica.copy()
df["author_list"] = df["Author full names"].apply(parse_authors)

df["author_list"].head()
# Out:
# 0                          [Mari Marco, Snidaro Lauro]
# 1                          [Mari Marco, Snidaro Lauro]
# 2    [Ceschia Sara, Di Gaspero Luca, Rosati Roberto...
# 3                                 [Pagliarini Roberto]
# 4    [Madni Hussain Ahmad, Shujat Hafsa, de Nardin ...
# Name: author_list, dtype: object

# %%
def contains_prof(authors):
    return any(a in professori_informatica for a in authors)

df_inf_prof = df[df["author_list"].apply(contains_prof)].copy()
df_inf_prof.shape
# Out:
# (1733, 35)

# %%
from itertools import combinations

edges = []

for authors in df_inf_prof["author_list"]:
    # tieni solo gli autori che sono professori DMIF
    profs_in_article = [a for a in authors if a in professori_informatica]
    
    # se almeno 2 prof presenti → crea arco tra loro
    if len(profs_in_article) > 1:
        for a, b in combinations(sorted(profs_in_article), 2):
            edges.append((a, b))

# %%
G = nx.Graph()

for a,b in edges:
    if G.has_edge(a,b):
        G[a][b]["weight"] += 1
    else:
        G.add_edge(a, b, weight=1)

print("Nodi DMIF:", G.number_of_nodes())
print("Archi DMIF:", G.number_of_edges())
# Out:
# Nodi DMIF: 36
# Archi DMIF: 66

# %%
degree = nx.degree_centrality(G)
betw = nx.betweenness_centrality(G)

nx.set_node_attributes(G, degree, "degree")
nx.set_node_attributes(G, betw, "betweenness")

# %%
import community as community_louvain

partition = community_louvain.best_partition(G)
nx.set_node_attributes(G, partition, "community")

# %%
import os

net = Network(height="750px", width="100%", notebook=True)
net.barnes_hut()

# aggiungi nodi
for node, data in G.nodes(data=True):
    net.add_node(
        node,
        title=f"{node}<br>Degree: {data['degree']:.3f}<br>Betweenness: {data['betweenness']:.3f}",
        value=max(data["degree"], 0.01)*40,
        group=data["community"]
    )

# aggiungi archi
for a,b,data in G.edges(data=True):
    net.add_edge(a, b, value=data["weight"])

#os.makedirs("html", exist_ok=True)
#net.show("html/coauthors_informatica_DMIF.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %%
density_graph = nx.density(G)
print(density_graph)
# Out:
# 0.10476190476190476
