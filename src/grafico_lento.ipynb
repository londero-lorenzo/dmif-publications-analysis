# %%
import pandas as pd
import networkx as nx
from itertools import combinations
from pyvis.network import Network
import re, os

# %%
df_informatica = pd.read_csv('./data/informatica.csv')

df_informatica.head()
# Out:
#                                              Authors  \
# 0                              Mari, M.; Snidaro, L.
# 1                              Mari, M.; Snidaro, L.
# 2  Ceschia, S.; Di Gaspero, L.; Rosati, R.M.; Sch...
# 3                                     Pagliarini, R.
# 4  Madni, H.A.; Shujat, H.; de Nardin, A.; Zottin...
#
#                                    Author full names  \
# 0  Mari, Marco (59388337700); Snidaro, Lauro (650...
# 1  Mari, Marco (59388337700); Snidaro, Lauro (650...
# 2  Ceschia, Sara (35193496000); Di Gaspero, Luca ...
# 3                  Pagliarini, Roberto (25229039800)
# 4  Madni, Hussain Ahmad (57195220347); Shujat, Ha...
#
#                                         Author(s) ID  \
# 0                            59388337700; 6507499895
# 1                            59388337700; 6507499895
# 2   35193496000; 6505944235; 57406536600; 6701629145
# 3                                        25229039800
# 4  57195220347; 59705771800; 57259162600; 5795942...
#
#                                                Title  Year  \
# 0  Survey of Neural Network Approaches to Target ...  2026
# 1  Ensemble of KalmanNets with innovation-based a...  2026
# 2  Multi-neighborhood simulated annealing for the...  2026
# 3  Differential Flux-Balance Analysis Infers Meta...  2026
# 4  FsBAD: Data-efficient feature reconstruction f...  2026
#
#                                         Source title      Volume Issue  \
# 0                                 Information Fusion         127   NaN
# 1                                 Information Fusion         127   NaN
# 2  International Transactions in Operational Rese...          33     1
# 3                  Lecture Notes in Computer Science  16051 LNCS   NaN
# 4                        Pattern Recognition Letters         199   NaN
#
#   Art. No. Page start  ...                                               ISBN  \
# 0   103789        NaN  ...                                                NaN
# 1   103777        NaN  ...                                                NaN
# 2      NaN         38  ...                                                NaN
# 3      NaN        155  ...  9789819698936; 9789819698042; 9789819698110; 9...
# 4      NaN        113  ...                                                NaN
#
#    CODEN  PubMed ID Language of Original Document  Abbreviated Source Title  \
# 0    NaN        NaN                       English               Inf. Fusion
# 1    NaN        NaN                       English               Inf. Fusion
# 2    NaN        NaN                       English    Int. Trans. Oper. Res.
# 3    NaN        NaN                       English  Lect. Notes Comput. Sci.
# 4    NaN        NaN                       English     Pattern Recogn. Lett.
#
#       Document Type Publication Stage  \
# 0           Article             Final
# 1           Article             Final
# 2           Article             Final
# 3  Conference paper             Final
# 4           Article             Final
#
#                                 Open Access  Source                  EID
# 0  All Open Access; Hybrid Gold Open Access  Scopus  2-s2.0-105017548985
# 1                                       NaN  Scopus  2-s2.0-105017546340
# 2  All Open Access; Hybrid Gold Open Access  Scopus   2-s2.0-85211480324
# 3                                       NaN  Scopus  2-s2.0-105022894987
# 4  All Open Access; Hybrid Gold Open Access  Scopus  2-s2.0-105021263351
#
# [5 rows x 34 columns]

# %%
df = df_informatica.copy()

# Parser robusto: split su ; e , e ricostruisce "Cognome, Nome"
def parse_authors(x):
    if pd.isna(x):
        return []
    parts = re.split(";|,", x)
    parts = [p.strip() for p in parts if p.strip()]
    authors = []
    # Ricostruisco coppie "Cognome, Nome"
    for i in range(0, len(parts), 2):
        if i+1 < len(parts):
            authors.append(f"{parts[i]}, {parts[i+1]}")
    return authors

df["author_list"] = df["Author full names"].apply(parse_authors)

# %%
edges = []

for authors in df["author_list"]:
    if len(authors) > 1:
        for a, b in combinations(sorted(authors), 2):
            edges.append((a, b))

print("Collaborazioni (con duplicati):", len(edges))
# Out:
# Collaborazioni (con duplicati): 26173614

# %%
G = nx.Graph()

for a, b in edges:
    if G.has_edge(a, b):
        G[a][b]["weight"] += 1
    else:
        G.add_edge(a, b, weight=1)

print("Nodi nel grafo:", G.number_of_nodes())
print("Archi nel grafo:", G.number_of_edges())
# Out:
# Nodi nel grafo: 15392
# Archi nel grafo: 12638465

# %%
degree = nx.degree_centrality(G)
betw = nx.betweenness_centrality(G)

nx.set_node_attributes(G, degree, "degree")
nx.set_node_attributes(G, betw, "betweenness")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 degree = nx.degree_centrality(G)
# ----> 2 betw = nx.betweenness_centrality(G)
#       4 nx.set_node_attributes(G, degree, "degree")
#       5 nx.set_node_attributes(G, betw, "betweenness")
#
# File <class 'networkx.utils.decorators.argmap'> compilation 13:4, in argmap_betweenness_centrality_9(G, k, normalized, weight, endpoints, seed, backend, **backend_kwargs)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File ~\PycharmProjects\pythonProject\.venv\Lib\site-packages\networkx\utils\backends.py:551, in _dispatchable._call_if_no_backends_installed(self, backend, *args, **kwargs)
#     545 if "networkx" not in self.backends:
#     546     raise NotImplementedError(
#     547         f"'{self.name}' is not implemented by 'networkx' backend. "
#     548         "This function is included in NetworkX as an API to dispatch to "
#     549         "other backends."
#     550     )
# --> 551 return self.orig_func(*args, **kwargs)
#
# File ~\PycharmProjects\pythonProject\.venv\Lib\site-packages\networkx\algorithms\centrality\betweenness.py:224, in betweenness_centrality(G, k, normalized, weight, endpoints, seed)
#     221 for s in nodes:
#     222     # single source shortest paths
#     223     if weight is None:  # use BFS
# --> 224         S, P, sigma, _ = _single_source_shortest_path_basic(G, s)
#     225     else:  # use Dijkstra's algorithm
#     226         S, P, sigma, _ = _single_source_dijkstra_path_basic(G, s, weight)
#
# File ~\PycharmProjects\pythonProject\.venv\Lib\site-packages\networkx\algorithms\centrality\betweenness.py:416, in _single_source_shortest_path_basic(G, s)
#     414     Q.append(w)
#     415     D[w] = Dv + 1
# --> 416 if D[w] == Dv + 1:  # this is a shortest path, count paths
#     417     sigma[w] += sigmav
#     418     P[w].append(v)  # predecessors
#
# KeyboardInterrupt:

# %%
import community as community_louvain

partition = community_louvain.best_partition(G)
nx.set_node_attributes(G, partition, "community")

# %%
net = new Net(height="800px", width="100%", notebook=True)
net.barnes_hut()

for node, data in G.nodes(data=True):
    net.add_node(
        node,
        title=f"{node}<br>Degree: {data['degree']:.3f}<br>Betweenness: {data['betweenness']:.3f}",
        value=max(data["degree"], 0.01)*50,
        group=data["community"]
    )

for a, b, data in G.edges(data=True):
    net.add_edge(a, b, value=data["weight"])

net.show("html/coauthorship_all_authors.html", notebook=False)

"✔ Grafo generato: guarda html/coauthorship_all_authors.html"
